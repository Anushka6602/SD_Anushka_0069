# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka6602/SD_Anushka_0069/blob/main/Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
menu={
    "Pizza":100,
      "Tea":10,
      "Coffee":50,
      "chowmin":30
}
print(menu)
order_amount=0
item_1=input("choose your first item")
if item_1 in menu:
  order_amount=order_amount+menu[item_1]
  print(order_amount)
else:
  print("item is not available")
item_2=input("choose your second item")
if item_2 in menu:
  order_amount=order_amount+menu[item_2]
  print(order_amount)
else:
  print("item is not available")
# Out:
# {'Pizza': 100, 'Tea': 10, 'Coffee': 50, 'chowmin': 30}
# choose your first itempizza
# item is not available
# choose your second itemPizza
# 100
