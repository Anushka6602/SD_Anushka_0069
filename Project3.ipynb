# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka6602/SD_Anushka_0069/blob/main/Project3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("====This Is Your Personal ATM Machine====")

pin = 1234
balance = 100000000000000000

user_pin = int(input("Enter ATM PIN: "))

if user_pin == pin:

    while True:

        print("\n===== ATM SERVICES =====")
        print("1. Balance Check")
        print("2. Withdraw Money")
        print("3. Change PIN")
        print("4. Exit")

        choice = int(input("Enter your choice: "))

        if choice == 1:
            print("Your Balance is:", balance)

        elif choice == 2:
            amount = int(input("Enter Amount: "))

            if amount <= balance:
                balance = balance - amount
                print("Please Collect Your Cash")
                print("Remaining Balance:", balance)
            else:
                print("Insufficient Balance")

        elif choice == 3:
            old_pin = int(input("Enter Old PIN: "))

            if old_pin == pin:
                new_pin = int(input("Enter New PIN: "))
                pin = new_pin
                print("PIN Changed Successfully")
            else:
                print("Wrong Old PIN")

        elif choice == 4:
            print("Thank You for Using ATM")
            break

        else:
            print("Invalid Choice")

else:
    print("Wrong PIN")
# Out:
# ====This Is Your Personal ATM Machine====
# Enter ATM PIN: 1234
#
# ===== ATM SERVICES =====
# 1. Balance Check
# 2. Withdraw Money
# 3. Change PIN
# 4. Exit
# Enter your choice: 2
# Enter Amount: 100
# Please Collect Your Cash
# Remaining Balance: 99999999999999900
#
# ===== ATM SERVICES =====
# 1. Balance Check
# 2. Withdraw Money
# 3. Change PIN
# 4. Exit
# Enter your choice: 1
# Your Balance is: 99999999999999900
#
# ===== ATM SERVICES =====
# 1. Balance Check
# 2. Withdraw Money
# 3. Change PIN
# 4. Exit
# Enter your choice: 3
# Enter Old PIN: 1234
# Enter New PIN: 5678
# PIN Changed Successfully
#
# ===== ATM SERVICES =====
# 1. Balance Check
# 2. Withdraw Money
# 3. Change PIN
# 4. Exit
# Enter your choice: 1
# Your Balance is: 99999999999999900
#
# ===== ATM SERVICES =====
# 1. Balance Check
# 2. Withdraw Money
# 3. Change PIN
# 4. Exit
# Enter your choice: 2
# Enter Amount: 1000
# Please Collect Your Cash
# Remaining Balance: 99999999999998900
#
# ===== ATM SERVICES =====
# ...
