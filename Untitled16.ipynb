# %%
b=40

# %%
1+1
# Out:
# 2

# %%
a=10;

# %%
type(b)
# Out:
# int

# %%
y=9.7
type(y)
# Out:
# float

# %%
print("HELLO")
# Out:
# HELLO

# %%
q=89

# %%
t=90

# %%
print(q+t)
# Out:
# 179

# %%
r=3.5
type(r)
# Out:
# float

# %%
s="SRMCEM"
s[0]
# Out:
# 'S'

# %%
s[1]
# Out:
# 'R'

# %%
s[2]
# Out:
# 'M'

# %%
s[3]
# Out:
# 'C'

# %%
s[4]
# Out:
# 'E'

# %%
s[5]
# Out:
# 'M'

# %%
s[-1]
# Out:
# 'M'

# %%
s="SRMCEM"

# %%
s[::-1]
# Out:
# 'MECMRS'

# %%
s[0:3:+2]
# Out:
# 'SM'

# %%
s[0:3:-5]
# Out:
# ''

# %%
True*False
# Out:
# 0

# %%
True/False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1333/2794436645.py in <cell line: 0>()
# ----> 1 True/False
#
# ZeroDivisionError: division by zero

# %%
False/True
# Out:
# 0.0

# %%
S="TRUE"
type(S)
# Out:
# str

# %%
t="Batch name is computer Science & Engineering"

# %%
t[0:44:7]
# Out:
# 'Bacrcgn'

# %%
t[5:48:90]
# Out:
# ' '

# %%
t[-1:-44:-1]
# Out:
# 'gnireenignE & ecneicS retupmoc si eman hcta'

# %%
t[-3:-44:-5]
# Out:
# 'ii&ermina'

# %% [markdown]
# LIST

# %%
l=[1,45,678,"anushka",56.67,3+4j]

# %%
l[0]
# Out:
# 1

# %%
l[5].real
# Out:
# 3.0

# %%
l[5].imag
# Out:
# 4.0

# %%
type(l)
# Out:
# list

# %%
print(l)
# Out:
# [1, 45, 678, 'anushka', 56.67, (3+4j)]

# %%
type(l[5])
# Out:
# complex

# %%
s="Ramswar oop"

# %%
s.count('o')
# Out:
# 2

# %%
s.count(' ')
# Out:
# 1

# %%
s
# Out:
# 'Ramswar oop'

# %%
s.find('a')
# Out:
# 1

# %%
s.find('Ra')
# Out:
# 0

# %%
s.lower()
# Out:
# 'ramswar oop'

# %%
s.upper()
# Out:
# 'RAMSWAR OOP'

# %%
len(s)
# Out:
# 11

# %%
l[::-1]
# Out:
# [(3+4j), 56.67, 'anushka', 678, 45, 1]

# %%
l
# Out:
# [1, 45, 678, 'anushka', 56.67, (3+4j)]

# %%
l.append(67)

# %%
l
# Out:
# [1, 45, 678, 'anushka', 56.67, (3+4j), 67]

# %%
l.pop()
# Out:
# 67

# %%
l.pop()
# Out:
# (3+4j)

# %%
l.insert(0,456)

# %%
l
# Out:
# [456, 1, 45, 678, 'anushka', 56.67]

# %% [markdown]
# Tuple

# %%
t=(1,45,890,7,"Sureshmaheshramesh")

# %%
t.count(45)
# Out:
# 1

# %%
len(t[4])
# Out:
# 18

# %%
len(t)
# Out:
# 5

# %% [markdown]
# dictonary

# %%
dict={"name":'age',"Ramesh":56,"kamlesh":89}

# %%
dict['name']
# Out:
# 'age'

# %%
dict["kamlesh"]
# Out:
# 89

# %%
len(dict)
# Out:
# 3

# %% [markdown]
# LIST

# %%
l=[57,56,456,1,678,"Anushka",78.57,890]

# %%
l.remove(1)

# %%
l
# Out:
# [57, 56, 456, 678, 'Anushka', 78.57, 890]

# %%
l.insert
# Out:
# <function list.insert(index, object, /)>

# %%
l
# Out:
# [57, 56, 456, 678, 'Anushka', 78.57, 890]

# %% [markdown]
# LOOPS
