# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka6602/SD_Anushka_0069/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PANDAS

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv('/content/weather.csv')

# %%
df.loc[0:5,["MinTemp","MaxTemp","Rainfall"]]
# Out:
#    MinTemp  MaxTemp  Rainfall
# 0      8.0     24.3       0.0
# 1     14.0     26.9       3.6
# 2     13.7     23.4       3.6
# 3     13.3     15.5      39.8
# 4      7.6     16.1       2.8
# 5      6.2     16.9       0.0

# %%
df
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0        8.0     24.3       0.0          3.4       6.3          NW
# 1       14.0     26.9       3.6          4.4       9.7         ENE
# 2       13.7     23.4       3.6          5.8       3.3          NW
# 3       13.3     15.5      39.8          7.2       9.1          NW
# 4        7.6     16.1       2.8          5.6      10.6         SSE
# ..       ...      ...       ...          ...       ...         ...
# 361      9.0     30.7       0.0          7.6      12.1         NNW
# 362      7.1     28.4       0.0         11.6      12.7           N
# 363     12.5     19.9       0.0          8.4       5.3         ESE
# 364     12.5     26.9       0.0          5.0       7.1          NW
# 365     12.3     30.2       0.0          6.0      12.6          NW
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0             30.0         SW         NW           6.0  ...           29
# ...

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# 2           85.0          N        NNE           6.0  ...           69
# 3           54.0        WNW          W          30.0  ...           56
# 4           50.0        SSE        ESE          20.0  ...           49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.sample(5)
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 135     13.8     35.2       0.0          6.4      11.2          SE
# 244      6.6     13.1       0.2          2.8       8.2         WNW
# 278     -1.9     10.9       0.0          1.8       4.2           S
# 335      1.4     20.6       0.0          5.4      11.1           N
# 321      0.7     14.1       0.0          5.6       9.0         ENE
#
#      WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 135           48.0         SE        ESE           7.0  ...           15
# 244           61.0        NNW        WNW          31.0  ...           53
# 278           50.0        NaN        SSW           0.0  ...           72
# 335           46.0         SW          N           6.0  ...           16
# 321           20.0        SSW        NNW           6.0  ...           43
#
#      Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
df.shape
# Out:
# (366, 22)

# %%
df["MinTemp"]
# Out:
# 0       8.0
# 1      14.0
# 2      13.7
# 3      13.3
# 4       7.6
#        ...
# 361     9.0
# 362     7.1
# 363    12.5
# 364    12.5
# 365    12.3
# Name: MinTemp, Length: 366, dtype: float64

# %%
df[["MinTemp","MaxTemp","Rainfall"]]
# Out:
#      MinTemp  MaxTemp  Rainfall
# 0        8.0     24.3       0.0
# 1       14.0     26.9       3.6
# 2       13.7     23.4       3.6
# 3       13.3     15.5      39.8
# 4        7.6     16.1       2.8
# ..       ...      ...       ...
# 361      9.0     30.7       0.0
# 362      7.1     28.4       0.0
# 363     12.5     19.9       0.0
# 364     12.5     26.9       0.0
# 365     12.3     30.2       0.0
#
# [366 rows x 3 columns]

# %%
df.iloc[0]
# Out:
# MinTemp             8.0
# MaxTemp            24.3
# Rainfall            0.0
# Evaporation         3.4
# Sunshine            6.3
# WindGustDir          NW
# WindGustSpeed      30.0
# WindDir9am           SW
# WindDir3pm           NW
# WindSpeed9am        6.0
# WindSpeed3pm         20
# Humidity9am          68
# Humidity3pm          29
# Pressure9am      1019.7
# Pressure3pm      1015.0
# Cloud9am              7
# Cloud3pm              7
# Temp9am            14.4
# Temp3pm            23.6
# RainToday            No
# RISK_MM             3.6
# RainTomorrow        Yes
# Name: 0, dtype: object

# %%
df.iloc[0:10]
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0      8.0     24.3       0.0          3.4       6.3          NW
# 1     14.0     26.9       3.6          4.4       9.7         ENE
# 2     13.7     23.4       3.6          5.8       3.3          NW
# 3     13.3     15.5      39.8          7.2       9.1          NW
# 4      7.6     16.1       2.8          5.6      10.6         SSE
# 5      6.2     16.9       0.0          5.8       8.2          SE
# 6      6.1     18.2       0.2          4.2       8.4          SE
# 7      8.3     17.0       0.0          5.6       4.6           E
# 8      8.8     19.5       0.0          4.0       4.1           S
# 9      8.4     22.8      16.2          5.4       7.7           E
#
#    WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity3pm  \
# 0           30.0         SW         NW           6.0  ...           29
# 1           39.0          E          W           4.0  ...           36
# ...

# %%
df.iloc[:,0:5]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine
# 0        8.0     24.3       0.0          3.4       6.3
# 1       14.0     26.9       3.6          4.4       9.7
# 2       13.7     23.4       3.6          5.8       3.3
# 3       13.3     15.5      39.8          7.2       9.1
# 4        7.6     16.1       2.8          5.6      10.6
# ..       ...      ...       ...          ...       ...
# 361      9.0     30.7       0.0          7.6      12.1
# 362      7.1     28.4       0.0         11.6      12.7
# 363     12.5     19.9       0.0          8.4       5.3
# 364     12.5     26.9       0.0          5.0       7.1
# 365     12.3     30.2       0.0          6.0      12.6
#
# [366 rows x 5 columns]

# %%
df[df["MaxTemp"]>30]
# Out:
#      MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 13      12.1     30.9       0.0          6.2      12.4          NW
# 14      10.1     31.2       0.0          8.8      13.1          NW
# 15      12.4     32.1       0.0          8.4      11.1           E
# 16      13.8     31.2       0.0          7.2       8.4         ESE
# 18      12.4     32.3       0.6          7.4      13.0           E
# 19      15.6     33.4       0.0          8.0      10.4          NE
# 20      15.3     33.4       0.0          8.8       9.5         WNW
# 58      14.4     31.6       0.0          6.6      13.6         NNW
# 59      15.4     35.0       0.0          9.6      13.0           E
# 60      13.8     33.5       0.0         11.4      13.6          NE
# 61      13.6     34.2       0.0          8.8      12.8         NNE
# 62      14.3     35.0       0.0          7.6      10.5         ESE
# 66      14.3     34.1       0.0          6.6      10.5         ENE
# ...

# %%
plt.figure(figsize=(8,5))
plt.hist(df["MaxTemp"],bins=20)
plt.title("Distribution of Maximum Tamperature")
plt.xlabel("Maximum Temperature")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
