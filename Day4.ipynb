# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka6602/SD_Anushka_0069/blob/main/Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
l=[1,2,3,4]

# %%
type(l)
# Out:
# list

# %%
ar=np.array(l)

# %%
ar
# Out:
# array([1, 2, 3, 4])

# %%
type(ar)
# Out:
# numpy.ndarray

# %%
np.array([[1,2],[3,4]])
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.asarray(l)
# Out:
# array([1, 2, 3, 4])

# %%
a=[2,3,4]

# %%
np.asanyarray
# Out:
# <function numpy.asanyarray>

# %%
b=np.matrix(l)

# %%
b
# Out:
# matrix([[1, 2, 3, 4]])
